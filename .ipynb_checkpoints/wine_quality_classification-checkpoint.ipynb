# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
wine_qua_data = pd.read_csv('winequality-red.csv')
wine_qua_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_qua_data.shape
# Out:
# (1599, 12)

# %%
wine_qua_data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine_qua_data.duplicated().sum()
# Out:
# 240

# %%
wine_qua_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine_qua_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine_qua_data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine_qua_data['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
wine_qua_data.quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(wine_qua_data.corr(), annot=True, cbar=True, square=True, cmap='plasma')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.catplot(x='quality', data=wine_qua_data, kind='count')
plt.show()

# %%
wine_qua_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.figure(figsize=(10,38))
plt.subplot(10,2,1)
sns.barplot(x='quality', y='fixed acidity', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,2)
sns.barplot(x='quality', y='volatile acidity', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,3)
sns.barplot(x='quality', y='citric acid', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,4)
sns.barplot(x='quality', y='residual sugar', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,5)
sns.barplot(x='quality', y='chlorides', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,6)
sns.barplot(x='quality', y='free sulfur dioxide', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,7)
sns.barplot(x='quality', y='density', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,8)
sns.barplot(x='quality', y='pH', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,9)
sns.barplot(x='quality', y='sulphates', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,10)
sns.barplot(x='quality', y='alcohol', data=wine_qua_data)
plt.xlabel("Quality")

plt.subplot(10,2,11)
sns.barplot(x='quality', y='total sulfur dioxide', data=wine_qua_data)
plt.xlabel("Quality")

plt.show()
